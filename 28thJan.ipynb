# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52187/MACHINE-LEARNING/blob/main/28thJan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Salary_dataset.csv")

# %%
x=df.YearsExperience
y=df.Salary

# %%
import numpy as np
# Re-assign x and y from the DataFrame to ensure consistent lengths
x = df.YearsExperience
y = df.Salary

x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test  = train_test_split(x,y,test_size=0.2,random_state=0)
x_train
# Out:
# array([[ 9.7],
#        [ 4.1],
#        [ 5.4],
#        [ 8. ],
#        [ 3. ],
#        [ 5.2],
#        [ 3.3],
#        [ 4.6],
#        [ 8.3],
#        [ 6.9],
#        [ 1.4],
#        [10.6],
#        [ 3.1],
#        [ 2.3],
#        [ 6. ],
#        [ 6.1],
#        [ 3.8],
#        [ 3.3],
#        [ 9.1],
#        [ 2.1],
#        [ 1.2],
#        [ 7.2],
#        [ 5. ],
#        [ 4.1]])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Actual Salary:",y_test[:5])
print("Predicted Salary:",y_pred[:5])
# Out:
# Actual Salary: [[ 37732.]
#  [122392.]
#  [ 57082.]
#  [ 63219.]
#  [116970.]]
# Predicted Salary: [[ 40749.96184072]
#  [122700.62295594]
#  [ 64962.65717022]
#  [ 63100.14214487]
#  [115250.56285456]]

# %%
#Calculate Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 12823412.298126565

# %%
#Calculate RMSE

# %%
rmse=np.sqrt(mse)
print("Root Mean Square Error:\n")
print(rmse)
# Out:
# Root Mean Square Error:
#
# 3580.9792373213454

# %%
#Calculate R^2 value

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print("R-squared value:",r2)
# Out:
# R-squared value: 0.988169515729126

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_pred,color='red')
plt.xlabel("Years of Experience")
plt.ylabel("salary")
plt.title("Salary vs Experience")
plt.show()

# %%
plt.scatter(y_test,y_test,label="Actual Salary")
plt.scatter(y_test,y_pred,label="Predicted Salary")
plt.xlabel("Years of Experience")
plt.ylabel("salary")
plt.title("Salary vs Experience")
plt.legend()

# %%
slope=model.coef_
intercept=model.intercept_
print("Slope:",slope)
print("Intercept:",intercept)
# Out:
# Slope: [[9312.57512673]]
# Intercept: [25849.84163796]

# %%
experience = [[5]]

# %%
predicted_salary=model.predict(experience)
print("Predicted Salary:",predicted_salary)
# Out:
# Predicted Salary: [[72412.7172716]]

# %%
Salary_manual = slope * 5 + intercept
print("Predicted Salary:",Salary_manual)
# Out:
# Predicted Salary: [[72412.7172716]]

# %%
print("Actual salaries(sample):",y_test[:5])
print("Predicted salaries(sample):",y_pred[:5])
# Out:
# Actual salaries(sample): [[ 37732.]
#  [122392.]
#  [ 57082.]
#  [ 63219.]
#  [116970.]]
# Predicted salaries(sample): [[ 40749.96184072]
#  [122700.62295594]
#  [ 64962.65717022]
#  [ 63100.14214487]
#  [115250.56285456]]
